# %%
import pandas as pd
import numpy as np

# %%
rest_data = pd.read_csv("Dataset.csv")

# %%
rest_data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
rest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
rest_data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
rest_data.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
rest_data.duplicated().sum()
# Out:
# 0

# %%
rest_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
#Finding the average cost for two of living in the cities
rest_data.groupby("City")["Average Cost for two"].mean().sort_values(ascending=False).head().plot(kind="bar")
plt.title("Average cost for two per city, top 5")
plt.xlabel("City")
plt.ylabel("Amount")
plt.grid()
plt.show()

# %%
data = rest_data.groupby("Cuisines")["Votes"].sum().reset_index()

# %%
data[data["Votes"]==0]
# Out:
#                                                Cuisines  Votes
# 2                                 Afghani, North Indian      0
# 164                                     Awadhi, Mughlai      0
# 185                       Bakery, Chinese, North Indian      0
# 193                 Bakery, Desserts, Fast Food, Mithai      0
# 208                                Bakery, Healthy Food      0
# 213                                Bakery, North Indian      0
# 214                                       Bakery, Pizza      0
# 224                                    Bengali, Chinese      0
# 234                             Beverages, Healthy Food      0
# 323                            Burger, Pizza, Fast Food      0
# 457                          Cafe, Mexican, Continental      0
# 463                                 Cafe, North Eastern      0
# 489                                       Cafe, Tibetan      0
# 524                           Chinese, Fast Food, Pizza      0
# ...

# %%
import seaborn as sns

# %%
rest_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
sns.pairplot(rest_data[["Average Cost for two", "Aggregate rating", "Votes"]])

# %%
rest_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
rest_data["Has Online delivery"].value_counts().plot(kind="pie")
plt.title("Has online delivery")
plt.ylabel("")
plt.legend()
plt.show()

# %%
rest_data[["Aggregate rating", "Rating text"]].sort_values(by="Aggregate rating", ascending=True).head(2400)
# Out:
#       Aggregate rating Rating text
# 6615               0.0   Not rated
# 1994               0.0   Not rated
# 1995               0.0   Not rated
# 1996               0.0   Not rated
# 1997               0.0   Not rated
# ...                ...         ...
# 8121               2.5     Average
# 6413               2.5     Average
# 6541               2.5     Average
# 7307               2.5     Average
# 7940               2.5     Average
#
# [2400 rows x 2 columns]

# %%
rest_data = rest_data[rest_data["Rating text"] != "Not rated"]

# %%
rest_data["Rating text"].value_counts().plot(kind = "pie")
plt.title("Rating Averages")
plt.legend()
plt.ylabel("")
plt.show()

# %%
rest_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#The columns required for my purpose are:-
#Average Cost for two
#Has Table booking
#Has Online delivery
#Price range
x = rest_data[['Average Cost for two','Has Table booking','Has Online delivery','Price range']]

# %%
y = rest_data["Aggregate rating"]

# %%
x
# Out:
#       Average Cost for two Has Table booking Has Online delivery  Price range
# 0                     1100               Yes                  No            3
# 1                     1200               Yes                  No            3
# 2                     4000               Yes                  No            4
# 3                     1500                No                  No            4
# 4                     1500               Yes                  No            4
# ...                    ...               ...                 ...          ...
# 9546                    80                No                  No            3
# 9547                   105                No                  No            3
# 9548                   170                No                  No            4
# 9549                   120                No                  No            4
# 9550                    55                No                  No            2
#
# [7403 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelEncoder = LabelEncoder()

# %%
x["Has Table booking"] = labelEncoder.fit_transform(x["Has Table booking"])
# Out:
# C:\Users\Vedant Kasar\AppData\Local\Temp\ipykernel_26392\4047025316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Has Table booking"] = labelEncoder.fit_transform(x["Has Table booking"])

# %%
x["Has Table booking"].dtype
# Out:
# dtype('int32')

# %%
x.head()
# Out:
#    Average Cost for two  Has Table booking Has Online delivery  Price range
# 0                  1100                  1                  No            3
# 1                  1200                  1                  No            3
# 2                  4000                  1                  No            4
# 3                  1500                  0                  No            4
# 4                  1500                  1                  No            4

# %%
labelEncoder.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
x["Has Online delivery"] = labelEncoder.fit_transform(x["Has Online delivery"])
# Out:
# C:\Users\Vedant Kasar\AppData\Local\Temp\ipykernel_26392\911775977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Has Online delivery"] = labelEncoder.fit_transform(x["Has Online delivery"])

# %%
x.head()
# Out:
#    Average Cost for two  Has Table booking  Has Online delivery  Price range
# 0                  1100                  1                    0            3
# 1                  1200                  1                    0            3
# 2                  4000                  1                    0            4
# 3                  1500                  0                    0            4
# 4                  1500                  1                    0            4

# %%
labelEncoder.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
x["Has Online delivery"].dtype
# Out:
# dtype('int32')

# %%
#Has table booking 0 is no an 1 is yes
#Has Online booking 0 is no and 1 is yess

# %%
x.dtypes
# Out:
# Average Cost for two    int64
# Has Table booking       int32
# Has Online delivery     int32
# Price range             int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(x)

# %%
X
# Out:
# array([[-0.0190367 ,  2.37978283, -0.68302371,  1.10671644],
#        [-0.0135729 ,  2.37978283, -0.68302371,  1.10671644],
#        [ 0.13941344,  2.37978283, -0.68302371,  2.18135204],
#        ...,
#        [-0.06985002, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07258191, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07613338, -0.42020641, -0.68302371,  0.03208084]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
def modelresults(predictions):
    print("Mean absolute error on model is {}".format(mean_absolute_error(y_test, predictions)))
    print("Mean squared error on model is {}".format(np.sqrt(mean_squared_error(y_test, predictions))))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictionFromLr = lr.predict(X_test)

# %%
modelresults(predictionFromLr)
# Out:
# Mean absolute error on model is 0.39432816044619595
# Mean squared error on model is 0.49605014547789644

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
svmmodel = SVR()

# %%
param_gridsvr = {"C" : [0.1, 0.5], "kernel": ["linear","poly"], "degree" : [ 2 ] }

# %%
gridsvr = GridSearchCV(svmmodel, param_gridsvr)

# %%
gridsvr.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 0.5], 'degree': [2],
#                          'kernel': ['linear', 'poly']})

# %%
gridsvr.predict(X_test)
# Out:
# array([3.79840788, 3.79970501, 3.19987098, ..., 3.90275031, 3.3000885 ,
#        3.49953953])

# %%
predsgridsvr = gridsvr.predict(X_test)

# %%
modelresults(predsgridsvr)
# Out:
# Mean absolute error on model is 0.3922452961775423
# Mean squared error on model is 0.4978410290228295

# %%
#both models performed similar

# %%
param_grid = {
    "max_depth" : [10,30],
    "min_samples_leaf" : [1,2],
    "min_samples_split" : [2,5]
}

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
treemodel = DecisionTreeRegressor()

# %%
grid_tree = GridSearchCV(estimator = treemodel, param_grid = param_grid)

# %%
grid_tree.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [10, 30], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5]})

# %%
treepredictions = grid_tree.predict(X_test)

# %%
modelresults(treepredictions)
# Out:
# Mean absolute error on model is 0.3544491290266895
# Mean squared error on model is 0.45109963295845784

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfmodel = RandomForestRegressor()

# %%
param_gridrf = {
    "max_depth" : [5,15],
    "n_estimators": [2,5,10]
}

# %%
gridrf = GridSearchCV(rfmodel, param_gridrf)

# %%
gridrf.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 15], 'n_estimators': [2, 5, 10]})

# %%
rfprediction = gridrf.predict(X_test)

# %%
rfprediction
# Out:
# array([4.10215028, 3.63777596, 3.17972989, ..., 3.67943248, 3.38220531,
#        3.26812491])

# %%
modelresults(rfprediction)
# Out:
# Mean absolute error on model is 0.3543434952733129
# Mean squared error on model is 0.45075813274467125

# %%
gridrf.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 10}

# %%
grid_tree.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn_param_grid = {"n_neighbors": [9,12,14,16]}
knn_gri_search = GridSearchCV(knn, knn_param_grid)

# %%
knn_gri_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [9, 12, 14, 16]})

# %%
knnpreds = knn_gri_search.predict(X_test)

# %%
knnpreds
# Out:
# array([4.0375 , 3.61875, 3.2375 , ..., 3.875  , 3.08125, 3.21875])

# %%
modelresults(knnpreds)
# Out:
# Mean absolute error on model is 0.36404034436191757
# Mean squared error on model is 0.46300548252522156

# %%
knn_gri_search.best_params_
# Out:
# {'n_neighbors': 16}

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ads = AdaBoostRegressor()

# %%
ada_param_grid = {
    "n_estimators": [50,100,200],
    "learning_rate" : [0.1,0.5,1]
}

# %%
ada_grid_search = GridSearchCV(ads, ada_param_grid)

# %%
ada_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.1, 0.5, 1],
#                          'n_estimators': [50, 100, 200]})

# %%
adapreds = ada_grid_search.predict(X_test)

# %%
adapreds
# Out:
# array([4.0315508 , 3.61796875, 3.24323593, ..., 3.62347697, 3.38866163,
#        3.28096262])

# %%
modelresults(adapreds)
# Out:
# Mean absolute error on model is 0.3644883931324936
# Mean squared error on model is 0.45892950539935895

# %%
gridrf
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 15], 'n_estimators': [2, 5, 10]})

# %%
import joblib
joblib.dump(gridrf,"mlmodel.pkl")
# Out:
# ['mlmodel.pkl']

# %%
scaler
# Out:
# StandardScaler()

# %%
joblib.dump(scaler,"Scaler.pkl")
# Out:
# ['Scaler.pkl']

# %%
import app
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
app
# Out:
# <module 'app' from 'C:\\Users\\Vedant Kasar\\Cognifyz Internship\\app.py'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[256], line 1
# ----> 1 app.run()
#
# AttributeError: module 'app' has no attribute 'run'
